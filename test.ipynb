# %%
import sys
import os

# add the folder of the notebook to python path
sys.path.append(os.getcwd())

# %% [markdown]
# Device Setup

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
import os
os.listdir()
# Out:
# ['.config', 'sample_data']
